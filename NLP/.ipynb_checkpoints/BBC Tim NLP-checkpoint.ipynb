# %%
from os import listdir
from os.path import isfile, join
from pipe import *
import json
from pathlib import Path
import numpy as np

def GetFileStream(path='../worldnews-20170904'):
    files = listdir(path)
    for file in files:
        yield join(path, file)
  
@Pipe
def AdornFile(stream):
    for file in stream:
        yield (file, json.loads(Path(file).read_text(encoding='utf-8')))
        
@Pipe
def As_Npy(l):
    return np.array(list(l))

# %%
X = GetFileStream() \
  | AdornFile() \
  | take(300) \
  | select( lambda j: j[1]['text'] ) \
  | select( lambda t: nlp(t).vector ) \
  | select( lambda v: v/np.linalg.norm(v) ) \
  | As_Npy()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.

# %%
X = np.nan_to_num(X)

# %%
simmatrix = np.dot(X,X.transpose())

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
imgplot = plt.imshow(simmatrix)

# %%
X
# Out:
# array([[-0.01090725,  0.06819635,  0.00902872, ..., -0.00351286,
#         -0.03408958,  0.0258923 ],
#        [-0.03389194,  0.04158694,  0.00548752, ..., -0.01724978,
#         -0.02808398,  0.01312967],
#        [-0.01253674,  0.058189  , -0.01317131, ..., -0.02746821,
#          0.012637  ,  0.03052442],
#        ...,
#        [-0.02531968,  0.07418306, -0.00681237, ..., -0.01823664,
#          0.00701538,  0.01470257],
#        [ 0.01427644,  0.03012604, -0.01646831, ..., -0.01429347,
#         -0.03337219,  0.02743484],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ]], dtype=float32)

# %%
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import pairwise_distances

model = AgglomerativeClustering(n_clusters=5,
                                linkage="average", affinity='cosine')
model.fit(X)
plt.figure()
plt.axes([0, 0, 1, 1])
for l, c in zip(np.arange(model.n_clusters), 'rgbk'):
    plt.plot(X[model.labels_ == l].T, c=c, alpha=.5)
plt.axis('tight')
plt.axis('off')
plt.suptitle("AgglomerativeClustering(affinity=%s)" % metric, size=20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-f81db23c86a7> in <module>()
#       4 model = AgglomerativeClustering(n_clusters=5,
#       5                                 linkage="average", affinity='cosine')
# ----> 6 model.fit(X)
#       7 plt.figure()
#       8 plt.axes([0, 0, 1, 1])
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\hierarchical.py in fit(self, X, y)
#     740             memory.cache(tree_builder)(X, connectivity,
#     741                                        n_clusters=n_clusters,
# --> 742                                        **kwargs)
#     743         # Cut the tree
#     744         if compute_full_tree:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\externals\joblib\memory.py in __call__(self, *args, **kwargs)
#     360
#     361     def __call__(self, *args, **kwargs):
# --> 362         return self.func(*args, **kwargs)
#     363
#     364     def call_and_shelve(self, *args, **kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\hierarchical.py in _average_linkage(*args, **kwargs)
#     530 def _average_linkage(*args, **kwargs):
#     531     kwargs['linkage'] = 'average'
# --> 532     return linkage_tree(*args, **kwargs)
#     533
#     534
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\hierarchical.py in linkage_tree(X, connectivity, n_components, n_clusters, linkage, affinity, return_distance)
#     415             i, j = np.triu_indices(X.shape[0], k=1)
#     416             X = X[i, j]
# --> 417         out = hierarchy.linkage(X, method=linkage, metric=affinity)
#     418         children_ = out[:, :2].astype(np.int)
#     419
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\cluster\hierarchy.py in linkage(y, method, metric, optimal_ordering)
#     711
#     712     if not np.all(np.isfinite(y)):
# --> 713         raise ValueError("The condensed distance matrix must contain only "
#     714                          "finite values.")
#     715
#
# ValueError: The condensed distance matrix must contain only finite values.

# %%
# Out:
# array([[-0.01090725,  0.06819635,  0.00902872, ..., -0.00351286,
#         -0.03408958,  0.0258923 ],
#        [-0.03389194,  0.04158694,  0.00548752, ..., -0.01724978,
#         -0.02808398,  0.01312967],
#        [-0.01253674,  0.058189  , -0.01317131, ..., -0.02746821,
#          0.012637  ,  0.03052442],
#        ...,
#        [-0.02531968,  0.07418306, -0.00681237, ..., -0.01823664,
#          0.00701538,  0.01470257],
#        [ 0.01427644,  0.03012604, -0.01646831, ..., -0.01429347,
#         -0.03337219,  0.02743484],
#        [        nan,         nan,         nan, ...,         nan,
#                 nan,         nan